# %%
import openml

openml.config.apikey = ""
openml.config.server = "http://www.openml.org/api/v1/xml"

# %%
task = openml.tasks.get_task(13908)

# %%
print(task)
# Out:
# OpenMLTask instance.
# Task ID: 13908
# Task type: Supervised Classification
# Dataset id: 150

# %%
# a model which has a function fit(X,Y) and predict(X), predict_proba(X)

# %%
import numpy as np
class ZeroPredictor(object):
    def __init__(self, class_labels):
        self.class_labels = class_labels
    
    def fit(self, X, Y):
        return self
    
    def predict(self, X):
        return np.zeros(X.shape[0], dtype=np.int)
    
    def predict_proba(self, X):
        probas = np.zeros((X.shape[0], len(self.class_labels)))
        probas[:, 0] = 1
        return probas
        
    def get_params(self):
        return {}

# %%
features, labels = dataset.get_data(target=task.target_feature)

# %%
dummy_run = openml.runs.run_task(task, ZeroPredictor(task.class_labels))
# Out:
# 3484

# %%
return_code, response = dummy_run.publish()

# %%
import xmltodict
if(return_code == 200):
    response_dict = xmltodict.parse(response)
    run_id = response_dict['oml:upload_run']['oml:run_id']
    print("Uploaded run with id %s" % (run_id))
    print("Check it at www.openml.org/r/%s" % (run_id))
else:
    print("HTTP error %d" % return_code)
# Out:
# Uploaded run with id 560470
# Check it at www.openml.org/r/560470

# %%
from sklearn.ensemble import RandomForestClassifier
run = openml.runs.run_task(task, RandomForestClassifier(n_jobs=-1))
return_code, response = run.publish()
if(return_code == 200):
    response_dict = xmltodict.parse(response)
    run_id = response_dict['oml:upload_run']['oml:run_id']
    print("Uploaded run with id %s" % (run_id))
    print("Check it at www.openml.org/r/%s" % (run_id))
else:
    print("HTTP error %d" % return_code)
# Out:
# 2638
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# ...
